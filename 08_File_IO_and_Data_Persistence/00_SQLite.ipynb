// %% [markdown]
// ## SQLite API
//
// SQLite is written in C, it's API is manual and risky. To prevent that I will show you how to make use of it using classes.
//
// Before we get started you need:
//
//     - Sqlite installed
//     - CMakeLists.txt including sqlite3
//
// Here is CMakeLists.txt example:
//
// ```cmake
// cmake_minimum_required(VERSION 3.14)
//
// # Project Name and Version
// project(GymManagement VERSION 0.1)
//
// # Specify C++ Standard
// # In C, you might use -std=c99. Here we enforce C++17.
// set(CMAKE_CXX_STANDARD 17)
// set(CMAKE_CXX_STANDARD_REQUIRED True)
//
// # Define include directories
// # This is equivalent to the -I./include flag in GCC
// # PUBLIC means: "I use this, and anyone linking to me uses this"
// include_directories(include)
//
// find_package(SQLite3 REQUIRED)
//
// # Create the Executable
// # Syntax: add_executable(Name SourceFiles...)
// add_executable(gym_management
//     src/main.cpp
//     src/Database.cpp
// )
//
// target_link_libraries(gym_management PRIVATE SQLite::SQLite3)
// ```

// %% [markdown]
// ## Jupyter Notebooks
//
// This notebook keeps dependencies minimal, so the C++/SQLite snippets won't execute here. Use it for reading and copy/pasting only.
//
// To run the code, open the `08_File_IO_and_Data_Persistence/00_SQLite3_Project` directory (CMake project), build, and execute the same sources there.
//
// Let's get into our SQLite implementation.

// %% [markdown]
// These headers pull in the STL helpers and the SQLite C API we wrap:
// - `iostream` for console output.
// - `sqlite3.h` for the raw database handle and statement functions.
// - `string`/`stdexcept` for text management and runtime errors.
// - `vector`/`utility` so query results can be stored as `std::vector<std::pair<int, std::string>>`.

// %%
#include <iostream>
#include <sqlite3.h>
#include <string>
#include <stdexcept>
#include <vector>
#include <utility>

// %% [markdown]
// `Database` and `Statement` wrap the raw SQLite handles with RAII safety.
// - `Database` owns the `sqlite3*` connection and provides an `exec` helper plus `initializeSchema` to set up the `examples` table.
// - `handle()` returns the raw pointer so prepared statements can be built without transferring ownership.
// - `Statement` prepares a SQL string, binds parameters (`bindText`, `bindDouble`, `bindInt`), and iterates rows with `step()` while tracking completion via `done()`.
// - Column accessors (`columnText`, `columnInt`, `columnDouble`) convert SQLite column values into STL types.

// %%
class Database {
    private:
        sqlite3* db_{nullptr};
    public:
        // Explicit prevent implicit conversions, e.g.
        // Database db("gym.db"); is valid
        // Database db = "gym.db"; is invalid
        explicit Database(const std::string& path);
        ~Database();

        // execute a sql statement that does not return results
        void exec(const std::string& sql) {
            char * errMsg = nullptr;
            if (sqlite3_exec(db_, sql.c_str(), nullptr, nullptr, &errMsg) != SQLITE_OK) {
                std::string error = errMsg ? errMsg : "Unknown error";
                sqlite3_free(errMsg);
                throw std::runtime_error("SQL error: " + error);
            }
        }
        void initializeSchema(){
            exec(R"sql(
                CREATE TABLE IF NOT EXISTS examples(
                    id INTEGER PRIMARY KEY AUTOINCREMENT,
                    name TEXT NOT NULL
                );
            )sql");
        }
        sqlite3* handle() const noexcept { return db_; }
};

class Statement {
    private: 
        sqlite3_stmt* stmt_{nullptr};
        bool done_{false};
    public:
        // we recieve a pointer to the database and the sql string with placeholders
        // we prepare the sql statement using sqlite3_prepare_v2
        Statement(sqlite3* db, const std::string& sql);
        ~Statement();

        void bindText(int index, const std::string& value){
            if (sqlite3_bind_text(stmt_, index, value.c_str(), -1, SQLITE_TRANSIENT) != SQLITE_OK) {
                throw std::runtime_error("Failed to bind text at index " + std::to_string(index));
            }
        };
        void bindDouble(int index, double value){
            if (sqlite3_bind_double(stmt_, index, value) != SQLITE_OK) {
                throw std::runtime_error("Failed to bind double at index " + std::to_string(index));
            }
        };
        void bindInt(int index, int value){
            if (sqlite3_bind_int(stmt_, index, value) != SQLITE_OK) {
                throw std::runtime_error("Failed to bind int at index " + std::to_string(index));
            }
        };
        bool step(){
            int rc = sqlite3_step(stmt_);
            // our sql statement could return either SQLITE_ROW (a row is available)
            // or SQLITE_DONE (no more rows)
            if (rc == SQLITE_ROW) {
                return true; // Row is available
            } else if (rc == SQLITE_DONE) {
                done_ = true;
                return false; // No more rows
            } else {
                throw std::runtime_error("Failed to execute statement");
            }
        }
        // we can use this method to check if we are done iterating over the results
        bool done() const {
            return done_;
        }
        std::string columnText(int index) const {
            const unsigned char* text = sqlite3_column_text(stmt_, index);
            return text ? reinterpret_cast<const char*>(text) : "";
        }
        int columnInt(int index) const { return sqlite3_column_int(stmt_, index); }
        double columnDouble(int index) const { return sqlite3_column_double(stmt_, index); }
};

// %% [markdown]
// `ExampleController` centralizes operations for the `examples` table using prepared statements.
// - `addExample` inserts a new name and returns the generated row id.
// - `fetchAll` selects every row ordered by id and materializes them as `std::vector<std::pair<int, std::string>>`.
// - `count` executes `COUNT(*)` to report how many rows exist.
// - `remove` deletes a row by id via a bound parameter.

// %%
// Controller focused on the `examples` table
class ExampleController {
private:
    Database& db_;
public:
    explicit ExampleController(Database& db) : db_(db) {}

    int addExample(const std::string& name) {
        Statement stmt(db_.handle(), "INSERT INTO examples(name) VALUES (?);");
        stmt.bindText(1, name);
        stmt.step();
        return static_cast<int>(sqlite3_last_insert_rowid(db_.handle()));
    }

    std::vector<std::pair<int, std::string>> fetchAll() {
        Statement stmt(db_.handle(), "SELECT id, name FROM examples ORDER BY id;");
        std::vector<std::pair<int, std::string>> rows;
        while (stmt.step()) {
            rows.emplace_back(stmt.columnInt(0), stmt.columnText(1));
        }
        return rows;
    }

    int count() {
        Statement stmt(db_.handle(), "SELECT COUNT(*) FROM examples;");
        stmt.step();
        return stmt.columnInt(0);
    }

    void remove(int id) {
        Statement stmt(db_.handle(), "DELETE FROM examples WHERE id = ?;");
        stmt.bindInt(1, id);
        stmt.step();
    }
};

// %% [markdown]
// Quick demo wiring everything together:
// - Open `gym.db` and ensure the schema exists.
// - Use `ExampleController` to insert sample names, then print the total count.
// - Iterate over `fetchAll()` results to display each id/name pair.

// %%
    Database db("gym.db");
    db.initializeSchema();

    ExampleController controller(db);

    controller.addExample("Alice");
    controller.addExample("Bob");

    std::cout << "Examples count: " << controller.count() << "\n";

    for (auto& [id, name] : controller.fetchAll()) {
        std::cout << id << ": " << name << "\n";
    }
